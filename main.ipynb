# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone -b orig_v2 https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction.git
# Out:
# Cloning into 'ASU-proj-Static-IR-Drop-Prediction'...
# remote: Enumerating objects: 2104, done.
# remote: Counting objects: 100% (314/314), done.
# remote: Compressing objects: 100% (178/178), done.
# remote: Total 2104 (delta 174), reused 242 (delta 132), pack-reused 1790 (from 1)
# Receiving objects: 100% (2104/2104), 631.26 MiB | 15.81 MiB/s, done.
# Resolving deltas: 100% (1573/1573), done.
# Updating files: 100% (2024/2024), done.

# %%
# %cd ASU-proj-Static-IR-Drop-Prediction/AttUnet
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet

# %%
# %cd ..
# !git pull
# %cd AttUnet
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 2.75 KiB | 2.75 MiB/s, done.
# From https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction
#    351a10b..67a7668  orig_v2    -> origin/orig_v2
# Updating 351a10b..67a7668
# Fast-forward
#  AttUnet/evaluate.py | 121 +++++++++++++++++-----
#  main.ipynb          | 293 ++++++++++------------------------------------------
#  2 files changed, 149 insertions(+), 265 deletions(-)
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet

# %%
# !python train.py
# Out:
# cuda
# ['testcase1', 'testcase11', 'testcase12', 'testcase17', 'testcase18', 'testcase2', 'testcase3', 'testcase4', 'testcase5', 'testcase6']
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# 0.0005195221747271717 0.0
# 0.000888752518221736 0.0
# Figure(1000x400)
# ****** After Finetuning Epoch: 500, L1 Loss: 0.00070414, F1 Score: 0.0000

# %%
# !python evaluate.py --model /content/drive/MyDrive/saved/ft_real/499.pth --save_plots --plot_dir /content/drive/MyDrive/saved/plots/
# Out:
# Device: cuda:0
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# Loaded model from /content/drive/MyDrive/ir-drop-test/599.pth
#
# Case                    L1         F1        MSE
# --------------------------------------------------
# testcase10        0.000541     0.2392   0.000000
# Figure(1800x500)
# testcase13        0.000310     0.0000   0.000000
# Figure(1800x500)
# testcase14        0.000743     0.0000   0.000002
# Figure(1800x500)
# testcase15        0.001537     0.0838   0.000003
# Figure(1800x500)
# testcase16        0.002534     0.1141   0.000007
# Figure(1800x500)
# testcase19        0.000248     0.0397   0.000000
# Figure(1800x500)
# testcase20        0.000325     0.0690   0.000000
# Figure(1800x500)
# testcase7         0.000298     0.3752   0.000000
# Figure(1800x500)
# testcase8         0.000448     0.4194   0.000000
# Figure(1800x500)
# testcase9         0.000312     0.1726   0.000000
# Figure(1800x500)
# --------------------------------------------------
# Average           0.000730     0.1513
