# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone -b orig_v2 https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction.git
# Out:
# Cloning into 'ASU-proj-Static-IR-Drop-Prediction'...
# remote: Enumerating objects: 2282, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 2282 (delta 15), reused 19 (delta 9), pack-reused 2255 (from 2)
# Receiving objects: 100% (2282/2282), 1.07 GiB | 31.60 MiB/s, done.
# Resolving deltas: 100% (1722/1722), done.
# Updating files: 100% (2156/2156), done.

# %%
# %cd ASU-proj-Static-IR-Drop-Prediction/AttUnet
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet

# %%
# !pwd
# Out:
# /content

# %%
# %cd ..
# !git pull
# %cd AttUnet
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 2.22 KiB | 2.22 MiB/s, done.
# From https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction
#    b1d83e0..2e336cf  orig_v2    -> origin/orig_v2
# Updating b1d83e0..2e336cf
# Fast-forward
#  AttUnet/evaluate.py | 247 +++++++++++++++++++++++++++++++---------------------
#  1 file changed, 149 insertions(+), 98 deletions(-)
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet

# %%
# !python train.py
# Out:
# cuda
# Epoch [1/400], Loss: 0.0372, F1 Score: 0.0007, MSE: 0.0042, L1: 0.0475
# Epoch [2/400], Loss: 0.0036, F1 Score: 0.0000, MSE: 0.0021, L1: 0.0341
# Epoch [3/400], Loss: 0.0024, F1 Score: 0.0029, MSE: 0.0024, L1: 0.0367
# Epoch [4/400], Loss: 0.0018, F1 Score: 0.0273, MSE: 0.0010, L1: 0.0234
# Epoch [5/400], Loss: 0.0016, F1 Score: 0.0214, MSE: 0.0009, L1: 0.0222
# Epoch [6/400], Loss: 0.0016, F1 Score: 0.0172, MSE: 0.0017, L1: 0.0329
# Epoch [7/400], Loss: 0.0017, F1 Score: 0.0402, MSE: 0.0015, L1: 0.0256
# Epoch [8/400], Loss: 0.0015, F1 Score: 0.0558, MSE: 0.0013, L1: 0.0232
# Epoch [9/400], Loss: 0.0014, F1 Score: 0.0280, MSE: 0.0020, L1: 0.0329
# Epoch [10/400], Loss: 0.0012, F1 Score: 0.1489, MSE: 0.0007, L1: 0.0191
# Epoch [11/400], Loss: 0.0012, F1 Score: 0.0609, MSE: 0.0009, L1: 0.0193
# Epoch [12/400], Loss: 0.0013, F1 Score: 0.0794, MSE: 0.0010, L1: 0.0240
# Epoch [13/400], Loss: 0.0012, F1 Score: 0.0937, MSE: 0.0010, L1: 0.0256
# ...

# %%
# !python evaluate.py --model /content/drive/MyDrive/saved/ft_real/399.pth --save_plots --plot_dir /content/drive/MyDrive/saved/plots/
# Out:
# Device: cuda:0
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
#
# Loaded model from /content/drive/MyDrive/saved/ft_real/399.pth
#
# Case                    L1         F1        MSE
# --------------------------------------------------
# testcase10        0.000651     0.3186   0.000001
# Figure(1800x500)
# testcase13        0.000443     0.2179   0.000000
# Figure(1800x500)
# testcase14        0.000605     0.3226   0.000001
# Figure(1800x500)
# testcase15        0.001258     0.2356   0.000002
# Figure(1800x500)
# testcase16        0.002329     0.3226   0.000006
# Figure(1800x500)
# testcase19        0.000163     0.1001   0.000000
# Figure(1800x500)
# testcase20        0.000219     0.0318   0.000000
# Figure(1800x500)
# ...

# %%
# !python evaluate.py --model_dir /content/drive/MyDrive/saved/ft_real/
# Out:
# Device: cuda:0
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# Found 13 models in /content/drive/MyDrive/saved/ft_real/
#
# Model                                        Avg L1     Avg F1
# -----------------------------------------------------------------
# 0.pth                                      0.001820     0.0024
# 149.pth                                    0.000816     0.2109
# 199.pth                                    0.000650     0.1847
# 249.pth                                    0.000582     0.2081
# 299.pth                                    0.000690     0.2153
# 349.pth                                    0.000626     0.2398
# 399.pth                                    0.000688     0.2680
# ...

# %%
# %cd ASU-proj-Static-IR-Drop-Prediction/AttUnet/
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet
