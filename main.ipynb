# %%
# !git clone -b orig_v2 https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction.git
# Out:
# Cloning into 'ASU-proj-Static-IR-Drop-Prediction'...
# remote: Enumerating objects: 1965, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 1965 (delta 71), reused 126 (delta 52), pack-reused 1790 (from 1)
# Receiving objects: 100% (1965/1965), 631.04 MiB | 19.01 MiB/s, done.
# Resolving deltas: 100% (1470/1470), done.
# Updating files: 100% (1932/1932), done.

# %%
# !pwd
# Out:
# DataLoad_normalization.py  metrics.py	saved		  utilities.py
# evaluate.py		   model.py	train_attunet.py
# generate_saliency_maps.py  __pycache__	train.py

# %%
# !git pull
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 2), reused 6 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 427 bytes | 427.00 KiB/s, done.
# From https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction
#    5f64fc3..0e1be3d  orig_v2    -> origin/orig_v2
# Updating 5f64fc3..0e1be3d
# Fast-forward
#  AttUnet/saved/ft_real/placeholder.txt | 0
#  AttUnet/saved/pt/placeholder.txt      | 0
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 AttUnet/saved/ft_real/placeholder.txt
#  create mode 100644 AttUnet/saved/pt/placeholder.txt

# %%
# !python train.py
# Out:
# cuda
# ['testcase1', 'testcase11', 'testcase12', 'testcase17', 'testcase18', 'testcase2', 'testcase3', 'testcase4', 'testcase5', 'testcase6']
# ['list_testcase.txt', 'testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# Traceback (most recent call last):
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/train.py", line 137, in <module>
#     torch.save(model.state_dict(), '../saved/pt/'+str(epoch)+'.pth')
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 976, in save
#     with _open_zipfile_writer(f) as opened_zipfile:
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 838, in _open_zipfile_writer
#     return container(name_or_buffer)  # type: ignore[arg-type]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 802, in __init__
# ...
