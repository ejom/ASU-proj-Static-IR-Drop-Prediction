# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone -b orig_v2 https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction.git
# Out:
# Cloning into 'ASU-proj-Static-IR-Drop-Prediction'...
# remote: Enumerating objects: 2259, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 2259 (delta 3), reused 0 (delta 0), pack-reused 2255 (from 2)
# Receiving objects: 100% (2259/2259), 1.07 GiB | 33.89 MiB/s, done.
# Resolving deltas: 100% (1710/1710), done.
# Updating files: 100% (2156/2156), done.

# %%
# !ls
# Out:
# ASU-proj-Static-IR-Drop-Prediction  sample_data

# %%
# %cd ASU-proj-Static-IR-Drop-Prediction/AttUnet
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet

# %%
# %cd ..
# !git pull
# %cd AttUnet
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction
# Already up to date.
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet

# %%
# !python train.py
# Out:
# cuda
# Epoch [1/50], Loss: 0.1123, F1 Score: 0.0037, MSE: 0.0022, L1: 0.0330
# Epoch [2/50], Loss: 0.0370, F1 Score: 0.0097, MSE: 0.0021, L1: 0.0258
# Epoch [3/50], Loss: 0.0290, F1 Score: 0.0690, MSE: 0.0015, L1: 0.0207
# Epoch [4/50], Loss: 0.0289, F1 Score: 0.0374, MSE: 0.0007, L1: 0.0164
# Epoch [5/50], Loss: 0.0271, F1 Score: 0.0751, MSE: 0.0013, L1: 0.0257
# Epoch [6/50], Loss: 0.0292, F1 Score: 0.0493, MSE: 0.0024, L1: 0.0355
# Epoch [7/50], Loss: 0.0281, F1 Score: 0.1478, MSE: 0.0006, L1: 0.0171
# Epoch [8/50], Loss: 0.0272, F1 Score: 0.0173, MSE: 0.0025, L1: 0.0397
# Traceback (most recent call last):
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/train.py", line 131, in <module>
#     f_score += F1_Score(output.cpu().detach().numpy().copy(), ir.cpu().numpy().copy())[0]
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/metrics.py", line 26, in F1_Score
#     F_list.append(f1_score(x_[i,:].flatten(), y_[i,:].flatten(), average='binary'))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 216, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py", line 1324, in f1_score
#     return fbeta_score(
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 189, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py", line 1517, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 189, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py", line 1834, in precision_recall_fscore_support
#     MCM = multilabel_confusion_matrix(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py", line 189, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py", line 561, in multilabel_confusion_matrix
#     y_true = le.transform(y_true)
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py", line 134, in transform
#     return _encode(y, uniques=self.classes_)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_encode.py", line 240, in _encode
#     diff = _check_unknown(values, uniques)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_encode.py", line 306, in _check_unknown
#     unique_values = xp.unique_values(values)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/utils/_array_api.py", line 416, in unique_values
#     return numpy.unique(x)
#            ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_arraysetops_impl.py", line 289, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_arraysetops_impl.py", line 356, in _unique1d
#     ar.sort()
# KeyboardInterrupt

# %%
# !python evaluate.py --model /content/drive/MyDrive/saved/ft_real/499.pth --save_plots --plot_dir /content/drive/MyDrive/saved/plots/
# Out:
# Device: cuda:0
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# Traceback (most recent call last):
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/evaluate.py", line 34, in <module>
#     model.load_state_dict(torch.load(args.model, map_location=device))
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1500, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 768, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 749, in __init__
#     super().__init__(open(name, mode))  # noqa: SIM115
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/saved/ft_real/499.pth'
