# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone -b orig_v2 https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction.git
# Out:
# fatal: destination path 'ASU-proj-Static-IR-Drop-Prediction' already exists and is not an empty directory.

# %%
# !ls

# %%
# %cd ..
# !git pull
# %cd AttUnet
# Out:
# /content/ASU-proj-Static-IR-Drop-Prediction
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 346 bytes | 346.00 KiB/s, done.
# From https://github.com/ejom/ASU-proj-Static-IR-Drop-Prediction
#    8c525f8..7dce096  orig_v2    -> origin/orig_v2
# Updating 8c525f8..7dce096
# Fast-forward
#  AttUnet/train.py | 1 +
#  1 file changed, 1 insertion(+)
# /content/ASU-proj-Static-IR-Drop-Prediction/AttUnet

# %%
# !python train.py
# Out:
# cuda
# ['testcase1', 'testcase11', 'testcase12', 'testcase17', 'testcase18', 'testcase2', 'testcase3', 'testcase4', 'testcase5', 'testcase6']
# ['testcase10', 'testcase13', 'testcase14', 'testcase15', 'testcase16', 'testcase19', 'testcase20', 'testcase7', 'testcase8', 'testcase9']
# 0.0005195221747271717 0.0
# 0.000888752518221736 0.0
# Figure(1000x400)
# ****** After Finetuning Epoch: 500, L1 Loss: 0.00070414, F1 Score: 0.0000

# %%
# !python evaluate.py --model '/content/drive/MyDrive/saved/ft_real/499.pth'
# Out:
# Loaded model from /content/drive/MyDrive/saved/ft_real/499.pth
# Starting evaluation...
# Traceback (most recent call last):
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/evaluate.py", line 108, in <module>
#     main()
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/evaluate.py", line 105, in main
#     evaluate_model(model, dataloader_test_original_size)
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/evaluate.py", line 47, in evaluate_model
#     for batch_idx, (inputs, targets) in enumerate(dataloader):
#                                         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 741, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 801, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 54, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/content/ASU-proj-Static-IR-Drop-Prediction/AttUnet/DataLoad_normalization.py", line 256, in __getitem__
#     resistance_m1 = np.genfromtxt(os.path.join(folder_dir,'resistance_m1.csv'), delimiter = ',')
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 1989, in genfromtxt
#     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_datasource.py", line 192, in open
#     return ds.open(path, mode, encoding=encoding, newline=newline)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_datasource.py", line 532, in open
#     raise FileNotFoundError(f"{path} not found.")
# FileNotFoundError: ../data/hidden-real-circuit-data/testcase10/resistance_m1.csv not found.
